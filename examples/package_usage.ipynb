# %% [markdown]
# ## How To use gefolki anaconda package

# %%
import gefolki

# %% [markdown]
# ### mining function
# - 2 input images required (master as reference and slave to find within the master)
# - rank (3 as default)
# - fdecimation (8 as default)
#
# get the inputs

# %%
# !mkdir ./datasets
# !wget https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/JacksonvilleNavalAirStation_sandiaKu.png -P ./datasets/
# !wget https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/S1_Jacksonville_GEE.tif -P ./datasets/
# Out:
# --2019-11-22 11:05:54--  https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/JacksonvilleNavalAirStation_sandiaKu.png
# Resolving raw.githubusercontent.com... 151.101.128.133, 151.101.192.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202939 (198K) [image/png]
# Saving to: “./datasets/JacksonvilleNavalAirStation_sandiaKu.png”
#
# 100%[======================================>] 202,939     --.-K/s   in 0.02s
#
# 2019-11-22 11:05:55 (8.11 MB/s) - “./datasets/JacksonvilleNavalAirStation_sandiaKu.png” saved [202939/202939]
#
# --2019-11-22 11:05:55--  https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/S1_Jacksonville_GEE.tif
# Resolving raw.githubusercontent.com... 151.101.128.133, 151.101.192.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
master_final = gefolki.mining('datasets/S1_Jacksonville_GEE.tif', 'datasets/JacksonvilleNavalAirStation_sandiaKu.png')

# %% [markdown]
# ### Demo
# get all the inputs to start the demo

# %%
# !mkdir ./datasets
# !wget "https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/radar_bandep.png" -P ./datasets/
# !wget "https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/lidar_georef.png" -P ./datasets/
# !wget "https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/optiquehr_georef.png" -P ./datasets/
# Out:
# mkdir: cannot create directory `./datasets': File exists
# --2019-11-22 11:07:01--  https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/radar_bandep.png
# Resolving raw.githubusercontent.com... 151.101.192.133, 151.101.128.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com|151.101.192.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7657532 (7.3M) [application/octet-stream]
# Saving to: “./datasets/radar_bandep.png”
#
# 100%[======================================>] 7,657,532   27.6M/s   in 0.3s
#
# 2019-11-22 11:07:02 (27.6 MB/s) - “./datasets/radar_bandep.png” saved [7657532/7657532]
#
# --2019-11-22 11:07:02--  https://raw.githubusercontent.com/aplyer/gefolki/master/datasets/lidar_georef.png
# Resolving raw.githubusercontent.com... 151.101.192.133, 151.101.128.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com|151.101.192.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
gefolki.demo()
# Out:
# Debut recalage Lidar/Radar
# Fin recalage Lidar/Radar
#
#
# Debut recalage optique/Radar
# /opt/anaconda/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Fin recalage optique/Radar
